# %% [markdown]
# <a href="https://colab.research.google.com/github/mpaydar/CS381/blob/main/M_bayat_Quiz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# There are different types of diamonds. Diamond differ from each other based on the carat they are composed of . There are almost 54,000 different diamonds. In the given dataset we have 10 different attributes namely :
# 1. **cut**:
#  diamond's cut refers to how well-proportioned the dimensions of a diamond are, and how these surfaces, or facets, are positioned to create sparkle and brilliance
# Scale: Poor/Fair , Good, Very Good, Ideal
#
# 2. **color**:
# GIA's color-grading scale for diamonds is the industry standard. The scale begins with the letter D, representing colorless, and continues with increasing presence of color to the letter Z, or light yellow or brown.
#
# 3. **clarity**:Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
#
#
# 4. **depth**: The depth of a diamond refers to its measurement from top to bottom, from the table on the top of the diamond to the culet at its base
#
# 5. **table**:
# According to diamonds.pro ,a diamond’s table is the flat facet on its surface — the large, flat surface facet that you can see when you look at the diamond from above.
# Table percentage is important factor when looking for the quality of the diamond.
#
#
# 6. **price**: price of diamond
#
#
# 7. **x**:Total length of the diamond
# 8. **y**:Total width of the diamond
#
# 9. **z**:Total height of the diamond
#
#
# 10. **carat**:
# Carat denotes the weight of a diamond, not the size. Tiffany measures diamonds to 1/1000th of a carat; one carat equals . 20 grams. Tiffany diamonds are always cut to maximize beauty, not carat weight.
#
# The purpose of this EDA is to look into different characteristic that effect the quality and the value of diamond by making graphical comparison between the attributes.

# %% [markdown]
# According to the diamond pros,we have different types of carats ranging from
#  0.50 carats to 5.0 carat . One of the most important factors that effect the price of the diamond is the weight of the diamond. Price of a diamond could as go higher $17,500. The below graph has visualize this fact as well.

# %%
dataframe=pd.read_csv("https://raw.githubusercontent.com/mpaydar/CS381/main/Quiz/diamonds2.csv")
df3=dataframe['table'][:]
d4=dataframe['y'][:]
d5=dataframe['clarity'][:]
d6=dataframe['x'][:]
lengthToWidthRatio=np.divide(d6,d4)
d7=dataframe['cut'][:]
d8=dataframe['z'][:]
d9=dataframe['color']
d10=dataframe['depth']
df2=dataframe['price'][:]
d11=dataframe['carat'][:]

a=df2.describe()
b=df3.describe()
c=d4.describe()
d=d5.describe()
e=d6.describe()
f=d7.describe()
g=d8.describe()
h=d9.describe()
i=d10.describe()
j=d11.describe()



print(a)
print("------------ \n")
print(b)
print("------------ \n")
print(c)
print("------------ \n")
print(d)
print("------------ \n")
print(e)
print("------------ \n")
print(f)
print("------------ \n")
print(g)
print("------------ \n")
print(h)
print("------------ \n")
print(i)
print("------------ \n")
print(j)
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64
# ------------
#
# count    53940.000000
# mean        57.457184
# std          2.234491
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64
# ------------
#
# count    53940.000000
# mean         5.734526
# std          1.142135
# min          0.000000
# 25%          4.720000
# 50%          5.710000
# 75%          6.540000
# max         58.900000
# Name: y, dtype: float64
# ------------
#
# count     53940
# unique        8
# top         SI1
# freq      13065
# Name: clarity, dtype: object
# ------------
#
# count    53940.000000
# mean         5.731157
# std          1.121761
# min          0.000000
# 25%          4.710000
# 50%          5.700000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dataframe=pd.read_csv("https://raw.githubusercontent.com/mpaydar/CS381/main/Quiz/diamonds2.csv")

df3=dataframe['table'][:].to_numpy()
d4=dataframe['y'][:].to_numpy()
d5=dataframe['clarity'][:].to_numpy()
d6=dataframe['x'][:].to_numpy()
lengthToWidthRatio=np.divide(d6,d4)
d7=dataframe['cut'][:].to_numpy()
d8=dataframe['z'][:].to_numpy()
d9=dataframe['color'].to_numpy()
d10=dataframe['depth'].to_numpy()
df2=dataframe['price'][:].to_numpy()
d11=dataframe['carat'].to_numpy()





plt.bar(list(d11),list(df2),0.002)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in true_divide
#   if sys.path[0] == '':

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dataframe=pd.read_csv("https://raw.githubusercontent.com/mpaydar/CS381/main/Quiz/diamonds2.csv")

df3=dataframe['table'][:].to_numpy()
d4=dataframe['y'][:].to_numpy()
d5=dataframe['clarity'][:].to_numpy()
d6=dataframe['x'][:].to_numpy()
lengthToWidthRatio=np.divide(d6,d4)
d7=dataframe['cut'][:].to_numpy()
d8=dataframe['z'][:].to_numpy()
d9=dataframe['color'].to_numpy()
d10=dataframe['depth'].to_numpy()





sns.barplot(x='carat',
            y='price',
           data=dataframe)
plt.show()

# %% [markdown]
# Another important factor that indicate the quality of the price is the length to width ratio. Each diamond cut has an idea length to width ration.
# for brilliant. The below are some of the ideal length to width ration for different diamond:
# 1. cut diamonds = 1.0-1.5
# 2. pear-cut diamond = 1.45-1.75
# 3. Marquise-cut diamond’s = 1.85-2
# 4. Cushion cut is 1.0-1.8
# 5. Emerald cut =1.3-1.4
# 6. oval cut = 1.25-1.5

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dataframe=pd.read_csv("https://raw.githubusercontent.com/mpaydar/CS381/main/Quiz/diamonds2.csv")




d4=dataframe['y'][:].to_numpy()
d6=dataframe['x'][:].to_numpy()
d7=dataframe['cut'][:].to_numpy()

lengthToWidthRatio=np.divide(d6,d4)



sns.scatterplot(x='cut',
            y=lengthToWidthRatio,
           data=dataframe)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
# Using matplotlib
plt.scatter(d7,lengthToWidthRatio)
plt.xlabel('Cut')
plt.ylabel('Length To Width Ratio')

plt.show()

# %% [markdown]
# Diamonds apperance which has a direct relation to its value. There are certain factors that need be propely checked when considerring a diamond quality. One of those factos is the diamond height.
# Below, we’ve listed the ideal diamond depth ranges for all of the most common diamond shapes. Like with the ideal diamond table percentages we listed above, these ranges are intended as general guidelines only:
#
# For a round diamond, an ideal depth percentage is between 59 and 62.6 percent This very nice 1.30-carat round cut from Blue Nile, for example, has a depth of 61.8%.
# For a princess cut diamond, choose a diamond with an ideal depth of 68 to 75 percent. Here’s a beautiful 1.10-carat princess cut from Blue Nile with a depth of 73.3%.
# For a cushion cut diamond, look for an ideal depth that’s between 61 and 68 percent.
# For an Asscher or Emerald cut diamond, an ideal depth is between 61 to 68 percent. For example, see this excellent emerald cut diamond with a 64.6% depth from James Allen.
# For an oval cut diamond, an ideal depth is less than 68 percent. For example, this beautiful 1.01 carat oval cut diamond from Blue Nile has a depth of 65.8%.
# For a pear shape diamond, an ideal diamond’s depth is less than 68 percent. This impressive pear shape diamond from Blue Nile has a depth of 61.5%.
# For a radiant cut diamond, an ideal depth is less than 67 percent. This gorgeous 1.21-carat radiant cut diamond from Blue Nile has a depth of 68.8%.
# For a heart shape diamond, make sure to choose a diamond with an ideal depth of 56 to 62 percent. For example, this beautiful 1.20-carat heart shape diamond from Blue Nile has a depth of 57.6%.
# For a marquise diamond, an ideal depth range is between 58 and 62 percent of the total width of the diamond, while a very good cut will have a depth range of 56 to 57.9 or 62.1 to 66 percent. Here’s a 1.20-carat marquise cut from James Allen with a excellent depth at 61.3%.
#
# Below is a visualization graph depth versus the price which confirm the above facts.In the graph you can see all of the expensive graphs depth are between 55 to 65 depth range.

# %%
# matplotlib.pyplot
d10=dataframe['depth'].to_numpy()
plt.scatter(d10,df2)
plt.xlabel('depth')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
# Seaborn implementation
sns.scatterplot(x='depth',
            y='price',
           data=dataframe)

# %% [markdown]
# The size of the table is one of the most important factors in the appearance of any diamond. A large table not only lets light into the diamond, but it also disperses light onto the other facets of the diamond to create a beautiful sparkle.
#
# While it’s important for a diamond’s table to be large enough to allow light in, a bigger table isn’t necessarily better. A good table needs to be balanced — it needs to be large enough to let lots of light into the stone, but not so big that it doesn’t refract light onto the crown of the diamond.
#
# Table percentage is calculated by measuring the width of the table as a percentage of the total width of the diamond. The wider the table is relative to the diamond’s total width, the larger the diamond’s table percentage.
# In the boxplot you could see that , the table percetage which as calculated using the table size by the total width of the diamond lies 8 to 12 which indicate that having a very large table comparing to the width does mean a more expensive diamond.

# %%
df3=dataframe['table'][:].to_numpy()
d4=dataframe['y'][:].to_numpy()
tablePercentage=np.divide(df3,d4)
plt.boxplot(tablePercentage)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# {'boxes': [<matplotlib.lines.Line2D at 0x7f477a3aca90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f477a3504d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f477a306510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f477a36ab90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f477a338510>,
#   <matplotlib.lines.Line2D at 0x7f477a345a90>]}

# %%
sns.boxplot(y=tablePercentage,
                data=dataframe)

# %% [markdown]
# We can also visualize the relationship between the table percentage and price.
# By plotting the tablePercentage as boxplot,we can see that the average table percentage is between 50 to 60 which is showing
# important fact that diamond are made in way to have appropriate surface size since it effects the shining characteristic of
# a diamond.

# %%
plt.scatter(tablePercentage,df2,1)

# %% [markdown]
# You can see that The higher the table size is , it doesn't mean it's more expensive, proportionally it should be about 50-60% of the total width of the diamond.

# %%
# Seaborn implementation 
sns.scatterplot(x=tablePercentage,
            y='price',
           data=dataframe)

# %% [markdown]
# Depth and shape of the diamond also worth visualizing because an ideal depth varies for each shape althoug it is important to mention that it lies around upper 50's and 60's.

# %%
plt.scatter(d7,d10)

# %%
sns.scatterplot(x=d7,
            y=d10,
           data=dataframe)

# %% [markdown]
# What proportion of diamonds are between .30 and 1.08 carats?

# %%
from numpy.ma.core import where
result=[i for i in d11 if i<0.30 and i<1.08]
numberOfdiamond=dataframe['carat'].size
desire_portion=len(result)/numberOfdiamond
print(desire_portion*100,'%')
# Out:
# 1599
# 2.9644048943270302 %

# %% [markdown]
# How many of the diamonds have equal x and y dimensions?

# %%
equal_dimensions=np.intersect1d(d4, d6)
print(len(equal_dimensions))
# Out:
# 521

# %% [markdown]
# How many of the diamonds have a carat value that is less than the mean carat value?

# %%
ave=np.mean(d11)
diamond_count=[i for i in d11 if i<ave]
print(len(diamond_count))
# Out:
# 31127

# %% [markdown]
# How many diamonds have a Premium cut or better? Note that the possible values for the quality of a
# cut are ranked in ascending order as follows: Fair / Good / Very Good / Premium / Ideal

# %%
numberOfPremium=[i for i in d7 if i=='Premium']
numberOfIdeal=[i for i in d7 if i=='Ideal']
print(len(numberOfPremium)+len(numberOfIdeal))
# Out:
# 35342

# %% [markdown]
# Which diamond has the highest price per carat? What is its value?

# %%
result=df2 * d11
value=np.max(result)
row=np.where(result==value)[0][0]
di1=dataframe['carat'][row]
di2=dataframe['clarity'][row]
di3=dataframe['color'][row]
di4=dataframe['cut'][row]
di5=dataframe['price'][row]
di6=dataframe['depth'][row]
di7=dataframe['table'][row]
d = {'carat': [di1], 'clarity': [di2],'color':[di3],'cut':[di4],'price':[di5],'depth':[di6],'table':[di7],'price per carat':[value]}
df=pd.DataFrame(data=d)
print(df)
# Out:
#    carat clarity color   cut  price  depth  table  price per carat
# 0   5.01      I1     J  Fair  18018   65.5   59.0         90270.18

# %% [markdown]
# Using both Matplolib and Seaborn, make boxplots of the diamond price for each distinct cut value and
# discuss any conclusions you can draw from the appearance of the boxplots.

# %%
sns.boxplot(x='cut',
            y='price',
            data=dataframe)

# %% [markdown]
# From the graph it could be interpreted that the ideal cut has the price maximum at $5000 whereas the premium has higher maximum price. The mean of each diamond cut is slighly different when comparing it against the price range.

# %% [markdown]
# Using both Matplolib and Seaborn, make a scatter plot of price vs. carat. What can we say about the
# relationship between those two attributes?

# %%
plt.scatter(df2,d11)

# %%
# Seaborn implementation 
sns.scatterplot(x=df2,
            y=d11,
           data=dataframe)

# %% [markdown]
# From the visualization of price vs. carat data, we could see that the higher carat the diamond is , the more expensive it will get.

# %% [markdown]
# In the conclusion, we can see base on the data visualization that there are more than one factors that determine the quality of the diamond and as well as its price. There were different comparisons that were intentionally made to highlight the important facts such as table perctentage or length to width ratio which effect the appreance of the diamond.
#
# #sources:
#
# https://www.diamonds.pro/education/diamond-depth-and-table/#Is-Depth-important-in-a-diamond
#
# https://somethingborrowedpdx.com/how-to-measure-a-diamond/
#
# https://www.afishman.com/cut-diamonds.html
#
# https://www.diamonds.pro/education/diamond-prices/
#
# https://www.gia.edu/gia-about/4cs-color#:~:text=GIA's%20color%2Dgrading%20scale%20for,or%20light%20yellow%20or%20brown.
#
# https://www.bluenile.com/education/diamonds/cut#:~:text=A%20diamond's%20cut%20refers%20to,to%20create%20sparkle%20and%20brilliance.
